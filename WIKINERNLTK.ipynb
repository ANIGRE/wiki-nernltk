# %% [markdown]
# <a href="https://colab.research.google.com/github/ANIGRE/wiki-nernltk/blob/main/WIKINERNLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
sentence = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))

# %%
print(ne_tree)
# Out:
# (S
#   (GPE European/JJ)
#   authorities/NNS
#   fined/VBD
#   (PERSON Google/NNP)
#   a/DT
#   record/NN
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   power/NN
#   in/IN
#   the/DT
#   mobile/JJ
#   phone/NN
#   market/NN
#   and/CC
#   ordered/VBD
#   the/DT
#   company/NN
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)

# %%
ex = 'is a free, multilingual open-collaborative online encyclopedia created and maintained by a community of volunteer contributors using a wiki-based editing system. Wikipedia is the largest general reference work on the Internet,[3] and one of the 15 most popular websites as ranked by Alexa; in 2021, it was ranked as the 13th most visited.[4][note 3] The project carries no advertisements and is hosted by the Wikimedia Foundation, an American non-profit organization funded mainly through donations, 80% of which are small donations from individual users'

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(ex)
sent
# Out:
# [('is', 'VBZ'),
#  ('a', 'DT'),
#  ('free', 'JJ'),
#  (',', ','),
#  ('multilingual', 'JJ'),
#  ('open-collaborative', 'JJ'),
#  ('online', 'NN'),
#  ('encyclopedia', 'NN'),
#  ('created', 'VBD'),
#  ('and', 'CC'),
#  ('maintained', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('community', 'NN'),
#  ('of', 'IN'),
#  ('volunteer', 'NN'),
#  ('contributors', 'NNS'),
#  ('using', 'VBG'),
#  ('a', 'DT'),
#  ('wiki-based', 'JJ'),
#  ('editing', 'NN'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('Wikipedia', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('general', 'JJ'),
#  ('reference', 'NN'),
#  ('work', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Internet', 'NNP'),
#  (',', ','),
#  ('[', 'VBD'),
#  ('3', 'CD'),
#  (']', 'NN'),
#  ('and', 'CC'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('15', 'CD'),
#  ('most', 'RBS'),
#  ('popular', 'JJ'),
#  ('websites', 'NNS'),
#  ('as', 'IN'),
#  ('ranked', 'VBN'),
#  ('by', 'IN'),
#  ('Alexa', 'NNP'),
# ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   is/VBZ
#   a/DT
#   free/JJ
#   ,/,
#   (NP multilingual/JJ open-collaborative/JJ online/NN)
#   (NP encyclopedia/NN)
#   created/VBD
#   and/CC
#   maintained/VBN
#   by/IN
#   (NP a/DT community/NN)
#   of/IN
#   (NP volunteer/NN)
#   contributors/NNS
#   using/VBG
#   (NP a/DT wiki-based/JJ editing/NN)
#   (NP system/NN)
#   ./.
#   Wikipedia/NNP
#   is/VBZ
#   the/DT
#   largest/JJS
#   (NP general/JJ reference/NN)
#   (NP work/NN)
#   on/IN
#   the/DT
#   Internet/NNP
#   ,/,
#   [/VBD
#   3/CD
#   (NP ]/NN)
#   and/CC
#   one/CD
#   of/IN
#   the/DT
#   15/CD
#   most/RBS
#   popular/JJ
#   websites/NNS
#   as/IN
#   ranked/VBN
#   by/IN
#   Alexa/NNP
#   ;/:
#   in/IN
#   2021/CD
#   ,/,
#   it/PRP
#   was/VBD
#   ranked/VBN
#   as/IN
#   the/DT
#   13th/CD
#   most/JJS
#   visited/VBN
#   ./.
#   [/$
#   4/CD
#   ]/NNP
#   [/NNP
#   note/VBP
#   3/CD
#   ]/IN
#   (NP The/DT project/NN)
#   carries/VBZ
#   no/DT
#   advertisements/NNS
#   and/CC
#   is/VBZ
# ...

# %%
NPChunker = nltk.RegexpParser(pattern) 
result = NPChunker.parse(sent)
result.draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-25-ef9db3d1c363> in <module>()
#       1 NPChunker = nltk.RegexpParser(pattern)
#       2 result = NPChunker.parse(sent)
# ----> 3 result.draw()
#
# /usr/local/lib/python3.7/dist-packages/nltk/tree.py in draw(self)
#     688         """
#     689         from nltk.draw.tree import draw_trees
# --> 690         draw_trees(self)
#     691
#     692     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#     861     :rtype: None
#     862     """
# --> 863     TreeView(*trees).mainloop()
#     864     return
#     865
#
# /usr/local/lib/python3.7/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     754         self._trees = trees
#     755
# --> 756         self._top = Tk()
# ...

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('is', 'VBZ', 'O'),
#  ('a', 'DT', 'O'),
#  ('free', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('multilingual', 'JJ', 'B-NP'),
#  ('open-collaborative', 'JJ', 'I-NP'),
#  ('online', 'NN', 'I-NP'),
#  ('encyclopedia', 'NN', 'B-NP'),
#  ('created', 'VBD', 'O'),
#  ('and', 'CC', 'O'),
#  ('maintained', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('community', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('volunteer', 'NN', 'B-NP'),
#  ('contributors', 'NNS', 'O'),
#  ('using', 'VBG', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('wiki-based', 'JJ', 'I-NP'),
#  ('editing', 'NN', 'I-NP'),
#  ('system', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Wikipedia', 'NNP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('the', 'DT', 'O'),
#  ('largest', 'JJS', 'O'),
#  ('general', 'JJ', 'B-NP'),
#  ('reference', 'NN', 'I-NP'),
#  ('work', 'NN', 'B-NP'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Internet', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('[', 'VBD', 'O'),
#  ('3', 'CD', 'O'),
#  (']', 'NN', 'B-NP'),
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://en.wikipedia.org/wiki/Wikipedia')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 3980

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 347,
#          'DATE': 996,
#          'EVENT': 23,
#          'FAC': 33,
#          'GPE': 289,
#          'LANGUAGE': 70,
#          'LAW': 11,
#          'LOC': 21,
#          'MONEY': 16,
#          'NORP': 190,
#          'ORDINAL': 42,
#          'ORG': 869,
#          'PERCENT': 75,
#          'PERSON': 823,
#          'PRODUCT': 32,
#          'QUANTITY': 4,
#          'TIME': 6,
#          'WORK_OF_ART': 133})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Wikipedia', 247), ('English', 68), ('Wikimedia Foundation', 28)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# Combined, Wikipedia's editions comprise more than 55 million articles, and attract more than 17 million edits and more than 1.7 billion unique visitors per month.[9][10]

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Combined,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's editions comprise
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  55 million articles, and attract
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="338636a8cd164965afe902660fe7b998-0" class="displacy" width="3410" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Combined,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Wikipedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Combined', 'VERB', 'combine'),
#  ('Wikipedia', 'PROPN', 'Wikipedia'),
#  ('editions', 'NOUN', 'edition'),
#  ('comprise', 'VERB', 'comprise'),
#  ('55', 'NUM', '55'),
#  ('\xa0', 'SPACE', '  '),
#  ('million', 'NUM', 'million'),
#  ('articles', 'NOUN', 'article'),
#  ('attract', 'VERB', 'attract'),
#  ('17', 'NUM', '17'),
#  ('million', 'NUM', 'million'),
#  ('edits', 'NOUN', 'edit'),
#  ('1.7', 'NUM', '1.7'),
#  ('\xa0', 'SPACE', '  '),
#  ('billion', 'NUM', 'billion'),
#  ('unique', 'ADJ', 'unique'),
#  ('visitors', 'NOUN', 'visitor'),
#  ('month.[9][10', 'PROPN', 'month.[9][10')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'Wikipedia': 'ORG',
#  'more than': 'CARDINAL',
#  'more than 17 million': 'CARDINAL'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(Combined, 'O', ''), (,, 'O', ''), (Wikipedia, 'B', 'ORG'), ('s, 'O', ''), (editions, 'O', ''), (comprise, 'O', ''), (more, 'B', 'CARDINAL'), (than, 'I', 'CARDINAL'), (55, 'O', ''), ( , 'O', ''), (million, 'O', ''), (articles, 'O', ''), (,, 'O', ''), (and, 'O', ''), (attract, 'O', ''), (more, 'B', 'CARDINAL'), (than, 'I', 'CARDINAL'), (17, 'I', 'CARDINAL'), (million, 'I', 'CARDINAL'), (edits, 'O', ''), (and, 'O', ''), (more, 'B', 'CARDINAL'), (than, 'I', 'CARDINAL'), (1.7, 'O', ''), ( , 'O', ''), (billion, 'O', ''), (unique, 'O', ''), (visitors, 'O', ''), (per, 'O', ''), (month.[9][10, 'O', ''), (], 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Wikipedia - Wikipedia Wikipedia From
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the free encyclopedia Jump to navigation Jump to search Open-source online encyclopedia This article is about Wikipedia. For
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's home page, see
# ...
